# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv('../data/SIP.csv')

# %%
#convert timeStamp from object to actual time stamp
df['opening_date'] = pd.to_datetime(df['opening_date'])

# %%
type(df['opening_date'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Oyear'] = df['opening_date'].apply(lambda time: time.year)
df['OMonth'] = df['opening_date'].apply(lambda time: time.month)
df['ODay'] = df['opening_date'].apply(lambda time: time.day)

# %%
df.head()
# Out:
#    Unnamed: 0       Region gender opening_date  min_amt  tenure  Oyear  \
# 0           0        Delhi      F   2011-03-24   314948       2   2011
# 1           1        Delhi      F   2015-12-21   348390       9   2015
# 2           2  Maharashtra      M   2014-05-18   289578       9   2014
# 3           3  Maharashtra      M   2016-04-10   292179       9   2016
# 4           4  Maharashtra      M   2011-09-24   154011       4   2011
#
#    OMonth  ODay
# 0       3    24
# 1      12    21
# 2       5    18
# 3       4    10
# 4       9    24

# %%
tmp=df['Region'].value_counts().to_dict()

# %%
plt.title('SIP Invesment by Region')
sns.countplot(x='Region',data=df)

# %%
plt.title('SIP Invement by Region')
plt.pie(x=list(tmp.values()),labels=list(tmp.keys()),data=df,shadow=True,startangle=-40,autopct='%1.1f%%',explode=(0.1,0.1,0,0,0))
plt.Circle((0,0),0.80,color='black', fc='white',linewidth=1.25)

# %%
x=df['gender'].value_counts().to_dict()
plt.title(' by gender')
plt.pie(x=list(x.values()),labels=list(x.keys()),data=df,shadow=True,startangle=-40,autopct='%1.1f%%',explode=(0.1,0))
plt.Circle((0,0),0.80,color='black', fc='white',linewidth=1.25)

# %%
plt.title('Tenure of Invement')
sns.countplot(x='tenure',data=df)

# %%
tmp=df['tenure'].value_counts().to_dict()
plt.title('SIP Tenure')
plt.pie(x=list(tmp.values()),labels=list(tmp.keys()),data=df,shadow=True,startangle=-40,autopct='%1.1f%%',explode=(0.1,0.1,0.1,0,0,0,0,0,0))
plt.Circle((0,0),0.80,color='black', fc='white',linewidth=1.25)

# %%
plt.title('Acc Opening Year')
sns.countplot(x='Oyear',data=df)

# %%
plt.title('Acc Opening Year')
sns.countplot(x='Oyear',hue='Region',data=df)

# %%
plt.title('Acc Opening Month')
sns.countplot(x='OMonth',data=df)

# %%
plt.title('Acc Opening Day')
sns.countplot(x='ODay',data=df)

# %%
x=df.groupby('Region').mean()
x
# Out:
#              Unnamed: 0        min_amt    tenure        Oyear    OMonth  \
# Region
# Delhi         51.181818  256376.454545  4.090909  2015.636364  6.090909
# Gujarat       52.935484  225721.000000  5.258065  2015.838710  7.387097
# Karnataka     52.750000  255070.125000  5.000000  2017.000000  6.500000
# MP            44.454545  258470.090909  4.181818  2016.090909  8.454545
# Maharashtra   47.051282  229817.717949  5.358974  2015.282051  6.564103
#
#                   ODay
# Region
# Delhi        17.272727
# Gujarat      17.806452
# Karnataka    17.750000
# MP           20.090909
# Maharashtra  15.282051

# %%
plt.title('Amt of Invesment by Region')
x['min_amt'].plot()

# %%
x=df.groupby('gender').mean()
x
# Out:
#         Unnamed: 0        min_amt    tenure        Oyear    OMonth       ODay
# gender
# F        50.411765  253890.843137  4.901961  2015.960784  6.921569  17.098039
# M        48.551020  218687.387755  5.163265  2015.469388  7.020408  16.918367

# %%
plt.title('Invesment Amt by Gender')
x['min_amt'].plot()
