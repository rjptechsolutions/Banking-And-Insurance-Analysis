# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv('../data/CurrentAccount.csv')

# %%
#convert timeStamp from object to actual time stamp
df['opening_date'] = pd.to_datetime(df['opening_date'])

# %%
type(df['opening_date'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['year'] = df['opening_date'].apply(lambda time: time.year)
df['Month'] = df['opening_date'].apply(lambda time: time.month)
df['Day'] = df['opening_date'].apply(lambda time: time.day)

# %%
df.head()
# Out:
#         region gender  cr_acc_type     Occupation       amt opening_date  \
# 0      Gujarat      M  Proprietary      Transport  41995927   2016-09-17
# 1  Maharashtra      M  Proprietary  Professionals  88688351   2009-09-10
# 2  Maharashtra      M  Proprietary  Professionals  57138505   2015-11-27
# 3  Maharashtra      M  Proprietary    Manufacture  88572049   2010-09-22
# 4  Maharashtra      M  Proprietary    Manufacture  51039039   2016-11-18
#
#    is_active  year  Month  Day
# 0          0  2016      9   17
# 1          1  2009      9   10
# 2          0  2015     11   27
# 3          1  2010      9   22
# 4          1  2016     11   18

# %%
tmp=df['region'].value_counts().to_dict()

# %%
plt.title('Current Account by Region')
plt.pie(x=list(tmp.values()),labels=list(tmp.keys()),data=df,shadow=True,startangle=-40,autopct='%1.1f%%',explode=(0.1,0.1,0,0,0))
plt.Circle((0,0),0.80,color='black', fc='white',linewidth=1.25)

# %%
x=df['gender'].value_counts().to_dict()

# %%
plt.title('Current Account by Gender')
plt.pie(x=list(x.values()),labels=list(x.keys()),data=df,shadow=True,startangle=-40,autopct='%1.1f%%',explode=(0.2,0))
plt.Circle((0,0),0.80,color='black', fc='white',linewidth=1.25)

# %%
plt.title('Accounts by Gender ratio in each Region')
sns.countplot(x='region',hue='gender',data=df)

# %%
plt.title('Region wise Account type')
sns.countplot(x='region',hue='cr_acc_type',data=df)

# %%
plt.title('Region wise Active Account')
sns.countplot(x='region',hue='is_active',data=df)

# %%
plt.title('Region wise Occupation')
sns.countplot(x='region',hue='Occupation',data=df)

# %%
tm=df['cr_acc_type'].value_counts().to_dict()

# %%
plt.title('Current Account type') 
plt.pie(x=list(tm.values()),labels=list(tm.keys()),data=df,shadow=True,startangle=-40,autopct='%1.1f%%',explode=(0.1,0.1,0.1,0.2,0.3))
plt.Circle((0,0),15,color='black', fc='white',linewidth=1.25)

# %%
tmp=df['Occupation'].value_counts().to_dict()

# %%
plt.title('Current Account Customer Occupation') 
sns.countplot(x='Occupation',data=df)

# %%
plt.title('Customer Occupation') 
plt.pie(x=list(tmp.values()),labels=list(tmp.keys()),data=df,shadow=True,startangle=-40,autopct='%1.1f%%',explode=(0.1,0.1,0.1,0.2,0.3))
plt.Circle((0,0),15,color='black', fc='white',linewidth=1.25)

# %%
x=df['is_active'].value_counts().to_dict()

# %%
plt.title('Active Accounts')
plt.pie(x=list(x.values()),labels=list(x.keys()),data=df,shadow=True,startangle=-40,autopct='%1.1f%%',explode=(0.1,0))
plt.Circle((0,0),0.80,color='black', fc='white',linewidth=1.25)

# %%
plt.title('Current Account Opening By Years') 
sns.countplot(x='year',data=df)

# %%
plt.figure(figsize=(10,5))
plt.title('Customer Account opening by Year in each Region')
sns.countplot(x='year',hue='region',data=df)

# %%
plt.title('Current Account Opening By Month') 
sns.countplot(x='Month',data=df)

# %%
plt.figure(figsize=(12,5))
plt.title('Monthly Current Account Opening')
sns.countplot(x='Month',hue='region',data=df)

# %%
plt.title('Current Account Opening By Day') 
sns.countplot(x='Day',data=df)
